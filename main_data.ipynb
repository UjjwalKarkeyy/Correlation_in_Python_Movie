# %% [markdown]
# # 🎬 Movie Dataset Analysis – Full Documentation
#
# ## 📌 Project Overview
# This project involves the exploration and analysis of a movie dataset using Python. The goal is to understand the structure of the dataset, perform data cleaning, check for missing values, and lay the groundwork for deeper analysis such as visualization and modeling (if extended).
#
# ---
#
# ## 🧰 Environment & Tools
# - **Python Libraries Used**:
#   - `pandas` – for data manipulation and analysis
#   - `numpy` – for numerical operations
#   - `seaborn`, `matplotlib.pyplot` – for data visualization
# - **File Format**: CSV
# - **Notebook Tool**: Jupyter Notebook (.ipynb)
#
# ---
#
# ## 📁 Dataset Overview
# The dataset is read from `data/movies.csv` and is assumed to contain information about various movies. Although I have not been through the dataset thoroughly, the dataset likely includes attributes such as movie title, genre, release year, ratings, duration, etc.
#
# ---
#
# ## 🧭 Project Workflow
#
# ### 1. 📥 Data Import
# ```python
# df = pd.read_csv('data/movies.csv')
# ```
# The dataset is loaded into a pandas DataFrame for analysis.
#
# ### 2. 🔍 Initial Data Exploration
# ```python
# df.head()
# df.columns
# ```
# These commands give a quick look at the data and list all available features.
#
# ### 3. 🚨 Missing Value Analysis
# ```python
# for col in df.columns:
#     missing = np.mean(df[col].isnull())
#     print(f'{col} - {missing:.1%} missing values')
# ```
# This loop helps identify which columns have missing values and what percentage of values are missing. This is crucial before further analysis or modeling.
#
# ---
#
# ## 🧠 Key Insights (if available)
# While the notebook primarily focuses on loading and inspecting data, a few initial insights can include:
# - Identification of columns with significant missing data
# - Understanding of the dataset's structure for future cleaning and analysis
#
# ---
#
# ## ▶️ How to Run This Notebook
#
# 1. Ensure Python is installed (preferably 3.7+).
# 2. Install the required libraries:
# ```bash
# pip install pandas numpy seaborn matplotlib
# ```
# 3. Place the dataset in the `data/` folder as `movies.csv`.
# 4. Open the notebook using Jupyter:
# ```bash
# jupyter notebook main.ipynb
# ```
#
# ---
#
# ## 🧑‍💻 Author & License
# Author: Ujjwal Karki
# Profession: Student

# %% [markdown]
# # 🎬 Movie Dataset Analysis
#
# This notebook explores and analyzes a dataset of movies using Python libraries such as pandas, seaborn, and matplotlib. The analysis covers:
# - Data loading and inspection
# - Handling missing values
# - Exploratory Data Analysis (EDA)
#
# ---

# %% [markdown]
# ## 🔧 Importing Libraries
# The required Python libraries for data manipulation and visualization are imported here.

# %%
# Import essential libraries
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

from matplotlib.pyplot import figure
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusting the figure size for the plots we create
# Out:
# /home/root123/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ## 📂 Loading the Dataset
# The movie dataset is read from a CSV file into a pandas DataFrame.

# %%
# Read the dataset
# Reading the data
df = pd.read_csv('data/movies.csv')

# %% [markdown]
# ## 👀 Previewing the Data
# Display the first few rows of the dataset to get an initial understanding of its structure.

# %%
# Display the first 5 rows
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## 🧱 Viewing Column Names
# Check the list of all column names in the dataset.

# %%
# List all column names
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %% [markdown]
# ## 🧱 Viewing Missing Values
# Check the percentage of all missing values in the dataset.

# %%
# List all column names
# Checking for null values

for col in df.columns:
    missing =  np.mean(df[col].isnull())
    print("{} - {}%".format(col, missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %% [markdown]
# ## 🧱 Dropping missing rows

# %%
df = df.dropna()

# %% [markdown]
# ## 🧱 Viewing Missing Values Percentage after the drop

# %%
# List all column names
# Checking for null values

for col in df.columns:
    # df[col].isnull() returns true or false i.., if we had [1,2,none,4,none] then it will return [false, false, true, false, true]
    # our np.mean will take those true/false as 1/0 and calculate the average i.e., [0,0,1,0,1] -> (0 + 0 + 1 + 0 + 1) / 5 -> 0.4 = 4%
    
    missing =  np.mean(df[col].isnull())  
    print("{} - {}%".format(col, missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Checking data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data type of budget and gross column

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Creating correct year column

df['year_correct'] = df['released'].astype(str)
df['year_correct'] = df['year_correct'].str.extract('(\d{4})')

# %% [markdown]
# ## 👀 Previewing the Data
# Display the first few rows of the dataset to get an initial understanding of its structure.

# %%
# Display the first 5 rows
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Sorting data frame by gross column

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
pd.set_option('display.max_rows', 50)

# %%
# Removing duplicates

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Scatter plot for budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])
plt.title("Budget vs Gross Earning")
plt.xlabel("Budget")
plt.ylabel("Gross Earning")
plt.show()

# %%
# Plot budget vs gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws={"color":'red'}, line_kws={"color":'green'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Looking at correlation

df.corr(numeric_only=True, method='pearson') # Different methods for finding correlation: Pearson (default), kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
corr_matrix = df.corr(numeric_only=True, method='pearson')

sns.heatmap(corr_matrix, annot=True)

plt.title("Correlation Heatmap")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
# Changing object type to numerical type

df_numerized = df.copy()

for col in df_numerized.columns:

    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

# %%
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  year_correct
# 0   699       46  19000000   46998772     1426    146.0             0
# 1   214       47   4500000   58853106      452    104.0             0
# 2  1157       47  18000000  538375067      945    124.0             0
# 3  1474       47   3500000   83453539     1108     88.0             0
# 4   271       47   6000000   39846344     1083     98.0             0

# %% [markdown]
# ## 👀 Previewing the Data
# Display the first few rows of the dataset to get an initial understanding of its structure.

# %%
# Display the first 5 rows
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
corr_matrix = df_numerized.corr(numeric_only=True, method='pearson')

sns.heatmap(corr_matrix, annot=True)

plt.title("Correlation Heatmap")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
correlation_unstacked = df_numerized.corr()

corr_pairs = correlation_unstacked.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#                                 ...
# year_correct  budget          0.320312
#               gross           0.268721
#               company        -0.018806
#               runtime         0.075294
#               year_correct    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head(15)
# Out:
# genre         budget         -0.368523
# budget        genre          -0.368523
# gross         genre          -0.244101
# genre         gross          -0.244101
# rating        budget         -0.203946
# budget        rating         -0.203946
# gross         rating         -0.181906
# rating        gross          -0.181906
# genre         votes          -0.135990
# votes         genre          -0.135990
# rating        company        -0.092357
# company       rating         -0.092357
# year_correct  country        -0.073569
# country       year_correct   -0.073569
# year          genre          -0.073167
# dtype: float64

# %%
high_corr = sorted_pairs[sorted_pairs > 0.5]

high_corr
# Out:
# gross         votes           0.614751
# votes         gross           0.614751
# gross         budget          0.740247
# budget        gross           0.740247
# year          year_correct    0.998726
# year_correct  year            0.998726
# director      director        1.000000
# votes         votes           1.000000
# released      released        1.000000
# score         score           1.000000
# rating        rating          1.000000
# name          name            1.000000
# genre         genre           1.000000
# year          year            1.000000
# budget        budget          1.000000
# country       country         1.000000
# writer        writer          1.000000
# star          star            1.000000
# company       company         1.000000
# gross         gross           1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64
